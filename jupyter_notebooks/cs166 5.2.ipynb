# %%
import networkx as nx
from pylab import *

# %%
g1 = nx.complete_graph(3)
g2 = nx.complete_graph(3)
nx.draw(g2)
nx.draw(g1)
show()

# %%
g3 = nx.hypercube_graph(4)
nx.draw(g3)
show()

# %%
g4 = nx.ladder_graph(5)
nx.draw(g4)
show()

# %%
g5 = nx.barbell_graph(20,0)
nx.draw(g5)
show()

# %%
g6 = nx.wheel_graph(100)
nx.draw(g6)
show()
