# %%
import numpy as np
import matplotlib.pyplot as plt
class TrafficSimulation:
    
    def __init__(self, road_length = 100, density = 0.2, max_vel = 5, p_slowdown = 0.5, initial_config = False):
        self.road_length = road_length
        self.density = density
        self.max_vel = max_vel
        self.p_slowdown = p_slowdown
        if not initial_config:
            self.state = np.zeros(road_length)
            #initial empty locations (-1s)
            init_empty_loc = np.random.choice(list(range(road_length)),int((1-density)*road_length), replace=False)
            for loc in init_empty_loc:
                self.state[loc] = -1
        else:
            self.state = np.array(initial_config)
    
    def update(self):
        flows = 0
        #move cars
        new_state = np.array([-1]*self.road_length)
        for i in range(self.road_length):
            if self.state[i] >= 0:
                if i+self.state[i] >= self.road_length:
                       flows+=1
                new_state[int((i+self.state[i])%self.road_length)]=self.state[i]
        self.state = new_state
        
        #updating velocities
        for i in range(self.road_length):
            if self.state[i] >= 0:
                new_vel = self.state[i]
                #rule 1
                if self.state[i] < self.max_vel:
                    new_vel+=1

                #rule 2
                #check distance
                distance = 5
                for d in range(1,6):
                    if self.state[int((i+d)%self.road_length)] != -1:
                        distance = d-1
                        break
                if new_vel > distance:
                    new_vel = distance

                #rule 3
                if new_vel >= 1:
                    if np.random.random() < self.p_slowdown:
                        new_vel-=1
                #update_vel
                self.state[i] = new_vel
        return flows
    
    def display(self):
        print(''.join('.' if x==-1 else str(int(x)) for x in self.state))

# %%
#function to get the 
def get_q(p = 0.1, n_sims = 20, timesteps = 200, t_0 = 100, display = False):
    sim = TrafficSimulation(density = p, max_vel = 5, p_slowdown = 0.5)
    flows = []
    for i in range(n_sims):
        flow_counter = 0
        #simulate without collecting data for the first t_0 timesteps
        for _ in range(t_0):
            sim.update()
        for t in range(timesteps):
            flow_counter+=sim.update()
        flows.append(flow_counter/timesteps)
    mu = np.mean(flows)
    std = np.std(flows)
    confint = [mu-1.96*std,mu+1.96*std]
    return (mu,flows,confint)

# %%
n=40
N = int(2.5*n)
flow = np.zeros(N)
t1 = np.linspace(0,0.15,n)
t2 = np.linspace(0.15,0.4,n)
t3 = np.linspace(0.4,0.8,int(n/2))
t = np.append(t1,np.append(t2,t3))
for i in range(N):
    flow[i] = get_q(p=t[i])

# %%
n=10
n_sims = 30
N = int(2.5*n)
flow_avg = np.zeros(N)
flow = []
confints = []
t1 = np.linspace(0,0.15,n)
t2 = np.linspace(0.15,0.4,n)
t3 = np.linspace(0.4,0.8,int(n/2))
t = np.append(t1,np.append(t2,t3))
t = np.linspace(0,0.8,N)
tflow = np.array([np.array([x]*n_sims) for x in t])
for i in range(N):
    flow_avg[i], scattered, confint = get_q(p=t[i],n_sims =n_sims)
    flow.append(scattered)
    confints.append(confint)

# %%
plt.figure(figsize=(10,10))
plt.scatter(tflow.reshape(-1),np.array(flow).reshape(-1), color ="black", s=2,alpha=0.8)
plt.plot(t,flow_avg, color ="blue",alpha =0.5)
for j in range(len(confints)):
    plt.plot([t[j],t[j]],confints[j], color = "green",linestyle="dashed",alpha = 0.7)
    plt.scatter([t[j],t[j]],confints[j], color = "green", marker = "_", s=80)
plt.yticks([0,.1,.2,.3,.4])
plt.xticks([0,.2,.4,.6,.8])
plt.ylabel('flow [cars per time step]',labelpad=10)
plt.xlabel('density [cars per site]',labelpad=10)
plt.title('Simulation',pad=15)
plt.tick_params(labelsize=12)
plt.rcParams["font.family"] = "Courier New"
plt.rcParams["font.size"] = "20"
plt.show()
